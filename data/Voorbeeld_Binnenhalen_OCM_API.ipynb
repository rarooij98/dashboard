# %%
import requests
import pandas as pd

# %%
###Inladen API - kijk naar country code en maxresults
response = requests.get("https://api.openchargemap.io/v3/poi/?output=json&countrycode=NL&maxresults=100&compact=true&verbose=false&key=93b912b5-9d70-4b1f-960b-fb80a4c9c017")

# %%
###Omzetten naar dictionary
responsejson  = response.json()
responsejson
# Out:
# [{'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-03-04T15:56:00Z',
#   'ID': 238390,
#   'UUID': '54DE6F07-8F83-4D6C-AC5C-F46C3CC5AF40',
#   'DataProviderID': 1,
#   'OperatorID': 47,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 238774,
#    'Title': 'Mc Donalds Ijsselstein',
#    'AddressLine1': 'Lorentzlaan',
#    'Town': 'IJsselstein',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3401 MX',
#    'CountryID': 159,
#    'Latitude': 52.014896340300794,
#    'Longitude': 5.06245760912293,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 392175,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 392176,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-03-04T15:56:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-03-04T15:56:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-03-04T15:52:00Z',
#   'ID': 238389,
#   'UUID': '2A59654E-C064-4234-AD9F-9E814387FE0B',
#   'DataProviderID': 1,
#   'OperatorID': 47,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 238773,
#    'Title': 'Haje Allego Ultra E Nieuwegein Oost',
#    'AddressLine1': 'Waterliniedok',
#    'Town': 'Nieuwegein',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3433 NV',
#    'CountryID': 159,
#    'Latitude': 52.01118158983823,
#    'Longitude': 5.1220471338107245,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 392173,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 175.0,
#     'CurrentTypeID': 30,
#     'Quantity': 6},
#    {'ID': 392174,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1}],
#   'NumberOfPoints': 6,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-03-04T15:52:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-03-04T15:52:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-03-04T15:49:00Z',
#   'ID': 238388,
#   'UUID': '2C11156F-072A-416A-9489-B2D96889BD9F',
#   'DataProviderID': 1,
#   'OperatorID': 47,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 238772,
#    'Title': 'Mc Donalds Nieuwegein ',
#    'AddressLine1': 'Ravenswade',
#    'Town': 'Nieuwegein',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3439 LD',
#    'CountryID': 159,
#    'Latitude': 52.04920110246246,
#    'Longitude': 5.117388801827872,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 392171,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 392172,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-03-04T15:49:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-03-04T15:49:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-03-04T14:27:00Z',
#   'ID': 238387,
#   'UUID': '7CC524E9-1377-47C2-97A5-B616B76DD825',
#   'DataProviderID': 1,
#   'OperatorID': 47,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 238771,
#    'Title': 'Divers Woerden',
#    'AddressLine1': 'Europabaan',
#    'Town': 'Woerden',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3446 CE',
#    'CountryID': 159,
#    'Latitude': 52.075587540309186,
#    'Longitude': 4.901184234016853,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 392170,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 175.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-03-04T14:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-03-04T14:27:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-03-04T14:16:00Z',
#   'ID': 238386,
#   'UUID': 'A543C1A2-9612-4492-B227-394A6A0143D1',
#   'DataProviderID': 1,
#   'OperatorID': 47,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 238770,
#    'Title': 'Shell A12 Hellevliet',
#    'AddressLine1': 'Rijksweg A12',
#    'Town': 'Woerden',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3481 CV',
#    'CountryID': 159,
#    'Latitude': 52.08093975266934,
#    'Longitude': 4.983936303056225,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 392167,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 175.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2},
#    {'ID': 392168,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 70.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-03-04T14:16:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-03-04T14:16:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-03-04T14:11:00Z',
#   'ID': 238385,
#   'UUID': '929C3638-907E-4E94-AC57-21EA35065635',
#   'DataProviderID': 1,
#   'OperatorID': 47,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 238769,
#    'Title': 'Shell Recharge Veldhuizen',
#    'AddressLine1': 'Veldhuizerweg',
#    'Town': 'Harmelen',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3481 ZZ',
#    'CountryID': 159,
#    'Latitude': 52.0819105021566,
#    'Longitude': 5.003278715701072,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 392165,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 175.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2},
#    {'ID': 392166,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 70.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-03-04T14:11:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-03-04T14:07:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-02-23T20:59:00Z',
#   'ID': 235545,
#   'UUID': 'CF27F53F-B0FD-40E3-B0C6-BFC3350BB87B',
#   'DataProviderID': 1,
#   'OperatorID': 3387,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 235929,
#    'Title': 'Rivierenlaan 164',
#    'AddressLine1': 'Rivierenlaan 164',
#    'Town': 'Pijnacker',
#    'StateOrProvince': 'Zuid-Holland',
#    'Postcode': '2641 RK',
#    'CountryID': 159,
#    'Latitude': 52.008437986141985,
#    'Longitude': 4.438623144085568,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 388570,
#     'ConnectionTypeID': 25,
#     'Reference': 'SGZH1-03906 SGZH',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-02-23T20:59:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-02-23T20:42:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-02-21T13:18:00Z',
#   'ID': 235341,
#   'UUID': '760B6873-7F7A-4378-BB0B-2EC793085F0D',
#   'DataProviderID': 1,
#   'OperatorID': 103,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 235725,
#    'Title': 'Rosendaalsestraat 318',
#    'AddressLine1': 'Rosendaalsestraat 318',
#    'Town': 'Arnhem',
#    'Postcode': '6824 CW',
#    'CountryID': 159,
#    'Latitude': 51.989283738948245,
#    'Longitude': 5.926502582741591,
#    'RelatedURL': 'https://www.allego.eu/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 388152,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO011946',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'GeneralComments': 'Allego NLALLEGO011946\r\nNL-ALL-NLALLEGO011946',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-02-21T13:18:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-02-18T09:43:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-02-11T08:31:00Z',
#   'ID': 213619,
#   'UUID': '1DE21223-B9D5-446D-8B1C-4C29BF2329DA',
#   'DataProviderID': 1,
#   'OperatorID': 45,
#   'UsageTypeID': 1,
#   'UsageCost': '€0.65 per kWh',
#   'AddressInfo': {'ID': 213999,
#    'Title': 'Avia Marees Den Oever',
#    'AddressLine1': 'Havenweg 2',
#    'Town': 'Den Oever',
#    'StateOrProvince': 'Noord Holland',
#    'Postcode': '1779 XT',
#    'CountryID': 159,
#    'Latitude': 52.92906820812402,
#    'Longitude': 5.028645395294689,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 355834,
#     'ConnectionTypeID': 33,
#     'Reference': 'NL*AVI*ENLAVIM0000027*1',
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 138.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 367061,
#     'ConnectionTypeID': 33,
#     'Reference': 'NL*AVI*ENLAVIM0000027*2',
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 120.0,
#     'CurrentTypeID': 30}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-02-11T08:31:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-02-08T14:38:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-01-17T22:53:00Z',
#   'ID': 212424,
#   'UUID': 'DC6664F5-EAE1-4838-81B6-D6E2BB3B7202',
#   'DataProviderID': 1,
#   'OperatorID': 3504,
#   'UsageTypeID': 1,
#   'UsageCost': '€0.71/kWh',
#   'AddressInfo': {'ID': 212804,
#    'Title': 'Meester Cramerweg',
#    'AddressLine1': 'Meester Cramerweg',
#    'Town': 'Hoogeveen',
#    'StateOrProvince': 'Drenthe',
#    'Postcode': '7913 WB',
#    'CountryID': 159,
#    'Latitude': 52.710549409171165,
#    'Longitude': 6.517221954540901,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 353652,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 250,
#     'PowerKW': 120.0,
#     'CurrentTypeID': 30,
#     'Quantity': 4}],
#   'NumberOfPoints': 4,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-01-17T22:53:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-01-17T14:01:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-01-17T22:53:00Z',
#   'ID': 212423,
#   'UUID': 'C70CDFC4-7983-4EBB-B5B2-BDED2CF8AE57',
#   'DataProviderID': 1,
#   'OperatorID': 3504,
#   'UsageTypeID': 1,
#   'UsageCost': '€0.71/kWh',
#   'AddressInfo': {'ID': 212803,
#    'Title': 'Zeemansstraat',
#    'AddressLine1': 'Zeemansstraat 21',
#    'Town': 'Zaandam',
#    'StateOrProvince': 'Noord-Holland',
#    'Postcode': '1506 CS',
#    'CountryID': 159,
#    'Latitude': 52.440784547014516,
#    'Longitude': 4.821080344094412,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 353651,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 250,
#     'PowerKW': 60.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-01-17T22:53:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-01-17T14:00:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-01-17T22:53:00Z',
#   'ID': 212422,
#   'UUID': 'D5563442-3D8D-4026-8414-0ABA137DA984',
#   'DataProviderID': 1,
#   'OperatorID': 3504,
#   'UsageTypeID': 1,
#   'UsageCost': '€0.71/kWh incl. VAT',
#   'AddressInfo': {'ID': 212802,
#    'Title': 'Oude Groenewoudseweg',
#    'AddressLine1': 'Oude Groenewoudseweg 365',
#    'AddressLine2': 'Nijmegen-Oost',
#    'StateOrProvince': 'Gelderland',
#    'Postcode': '6524 WZ',
#    'CountryID': 159,
#    'Latitude': 51.83215405018595,
#    'Longitude': 5.859914320165842,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 353650,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 250,
#     'Voltage': 1000,
#     'PowerKW': 120.0,
#     'CurrentTypeID': 30,
#     'Quantity': 8}],
#   'NumberOfPoints': 8,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-01-17T22:53:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-01-17T13:57:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-01-05T09:06:00Z',
#   'ID': 211127,
#   'UUID': '824F3540-68D8-4929-84A9-B4E5DBEF4B97',
#   'DataProviderID': 1,
#   'OperatorID': 69,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 211507,
#    'Title': 'Parking Hoogvliet',
#    'AddressLine1': 'De Halte 269',
#    'Town': 'Ede',
#    'StateOrProvince': 'Gelderland',
#    'Postcode': '6711 NZ',
#    'CountryID': 159,
#    'Latitude': 52.04184477866,
#    'Longitude': 5.666623285234095,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 351964,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-01-05T09:06:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2023-01-05T09:04:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-12-30T16:27:00Z',
#   'ID': 211037,
#   'UUID': '5262217F-0A62-45EE-98E5-3FF601A11B46',
#   'DataProviderID': 1,
#   'OperatorID': 3571,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 211417,
#    'Title': 'Kamp 26 02',
#    'AddressLine1': 'Kamp 26 02',
#    'Town': 'Lelystad',
#    'CountryID': 159,
#    'Latitude': 52.504658770471906,
#    'Longitude': 5.482037530220737,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 351776,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-12-30T16:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-12-30T11:13:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-12-26T20:29:00Z',
#   'ID': 210962,
#   'UUID': '402BC01C-1768-45D7-96EA-143BFC684F2E',
#   'DataProviderID': 1,
#   'OperatorID': 47,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 211342,
#    'Title': 'Jan Tinbergenweg',
#    'AddressLine1': 'Jan Tinbergenweg 3',
#    'Town': 'Zwaag',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '1689 ZV',
#    'CountryID': 159,
#    'Latitude': 52.68088528852729,
#    'Longitude': 5.084495657004027,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 351647,
#     'ConnectionTypeID': 2,
#     'Reference': 'NLEFLEV1490043',
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 100.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 351648,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 180.0,
#     'CurrentTypeID': 30,
#     'Quantity': 3}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-12-26T20:29:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-12-26T14:44:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-12-13T14:18:00Z',
#   'ID': 210384,
#   'UUID': 'AAB6EA96-7F03-42DA-AF1E-BB8644854DDE',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 210764,
#    'Title': 'Theemsstraat',
#    'AddressLine1': 'Theemsstraat',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2014 RZ',
#    'CountryID': 159,
#    'Latitude': 52.37507619143503,
#    'Longitude': 4.613204035808508,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 350395,
#     'ConnectionTypeID': 25,
#     'Reference': 'NL*GFX*EPP004046*2',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 30,
#     'Voltage': 230,
#     'PowerKW': 6.0,
#     'CurrentTypeID': 10,
#     'Quantity': 1},
#    {'ID': 350396,
#     'ConnectionTypeID': 25,
#     'Reference': 'NL*GFX*EPP004046*1',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 30,
#     'Voltage': 230,
#     'PowerKW': 6.0,
#     'CurrentTypeID': 10,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-12-13T14:18:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-12-10T12:36:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-12-15T15:45:00Z',
#   'ID': 210349,
#   'UUID': '1BA14176-821A-4B5C-B22A-D4ECF02448DF',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 210729,
#    'Title': 'Parkeerterrein Regius College',
#    'AddressLine1': 'Julianalaan',
#    'Town': 'Schagen',
#    'StateOrProvince': 'Noord-Holland',
#    'Postcode': '1741 CL',
#    'CountryID': 159,
#    'Latitude': 52.783795024517815,
#    'Longitude': 4.797450942261776,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 350318,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 17.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2},
#    {'ID': 350319,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 13.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-12-15T15:45:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-12-09T16:18:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-01-17T22:54:00Z',
#   'ID': 209765,
#   'UUID': '36CA222A-F89B-420D-B8F1-380D90701DCC',
#   'DataProviderID': 1,
#   'OperatorID': 3504,
#   'UsageTypeID': 1,
#   'UsageCost': '0,55 €/kWh',
#   'AddressInfo': {'ID': 210145,
#    'Title': 'Bavoort LEAP24 Semi-Fast charger',
#    'AddressLine1': 'Treekerweg 28',
#    'AddressLine2': 'Leusden-Zuid',
#    'Town': 'Leusden',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3832 GW',
#    'CountryID': 159,
#    'Latitude': 52.12276082899771,
#    'Longitude': 5.400444811984585,
#    'RelatedURL': 'http://leap24.eu',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 349049,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 136,
#     'Voltage': 440,
#     'PowerKW': 30.0,
#     'CurrentTypeID': 30,
#     'Quantity': 5}],
#   'NumberOfPoints': 5,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-01-17T22:54:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-11-04T12:43:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-10-16T09:57:00Z',
#   'ID': 208214,
#   'UUID': '8C1FD358-ED02-4E4F-BD09-41ABFFF96520',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 208594,
#    'Title': 'Avelingen-West',
#    'AddressLine1': 'Avelingen-West',
#    'Town': 'Gorinchem',
#    'StateOrProvince': 'South Holland',
#    'Postcode': '4202MS',
#    'CountryID': 159,
#    'Latitude': 51.8360073270031,
#    'Longitude': 4.939790531752465,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 346514,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 11.0,
#     'Quantity': 1}],
#   'NumberOfPoints': 4,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-10-16T09:57:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-10-15T09:32:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-02-13T21:02:00Z',
#   'ID': 208212,
#   'UUID': 'FB80590A-D651-4DAC-86B7-20FA97E75F1B',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 208592,
#    'Title': '50 Van Heemstraweg',
#    'AddressLine1': '50 Van Heemstraweg',
#    'Town': 'West Maas en Waal',
#    'StateOrProvince': 'Gelderland',
#    'Postcode': '6658KH',
#    'CountryID': 159,
#    'Latitude': 51.87832100591848,
#    'Longitude': 5.522909074397148,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 346511,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 11.0,
#     'Quantity': 1}],
#   'NumberOfPoints': 4,
#   'GeneralComments': 'CPID LIB_2912',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-02-13T21:02:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-10-15T09:26:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-10-10T19:59:00Z',
#   'ID': 207411,
#   'UUID': 'F8A12675-1011-453F-A988-6FFCD92E2089',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 207791,
#    'Title': '4 Einsteinstraat',
#    'AddressLine1': '4 Einsteinstraat',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2014KS',
#    'CountryID': 159,
#    'Latitude': 52.36773974028,
#    'Longitude': 4.612164531240637,
#    'ContactTelephone1': '+31 (0) 30 41 00 887',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 345323,
#     'ConnectionTypeID': 25,
#     'Reference': 'NL-GFX-ENTLP007209-2',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 17.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345324,
#     'ConnectionTypeID': 25,
#     'Reference': 'NL-GFX-ENTLP007209-1',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 17.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-10-10T19:59:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-10-10T18:40:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-10-10T20:18:00Z',
#   'ID': 206938,
#   'UUID': '4540E353-26BD-4D16-AE8E-C4A4FE87FC4E',
#   'DataProviderID': 1,
#   'OperatorID': 103,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 207318,
#    'Title': "Johanna's weg",
#    'AddressLine1': "Johanna's weg",
#    'StateOrProvince': 'North Holland',
#    'Postcode': '1901 NX',
#    'CountryID': 159,
#    'Latitude': 52.561055179424045,
#    'Longitude': 4.636920323230129,
#    'RelatedURL': 'https://smoovapp.eu/',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 344651,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043541',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345370,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043562',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345371,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043561',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345372,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043542',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345373,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043611',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345374,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043582',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345375,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043581',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345376,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043612',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345377,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043591',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345378,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043592',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345379,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043572',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 345380,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO0043571',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1}],
#   'NumberOfPoints': 6,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-10-10T20:18:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-10-08T08:01:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-10-25T17:29:00Z',
#   'ID': 204836,
#   'UUID': '2768743F-6912-4980-9EE3-5AE14A5AAB82',
#   'DataProviderID': 1,
#   'OperatorID': 3574,
#   'UsageTypeID': 1,
#   'UsageCost': '€ 0.52/kWh',
#   'AddressInfo': {'ID': 205203,
#    'Title': 'Shakespeareplein',
#    'AddressLine1': 'Shakespeareplein',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3533 DA',
#    'CountryID': 159,
#    'Latitude': 52.088953646361034,
#    'Longitude': 5.0900749398151675,
#    'ContactTelephone1': '+31(071)-568 19 06',
#    'RelatedURL': 'https://www.wedrivesolar.nl',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 342075,
#     'ConnectionTypeID': 25,
#     'Reference': '00302',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2},
#    {'ID': 342076,
#     'ConnectionTypeID': 25,
#     'Reference': '00146',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-10-25T17:29:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-10-02T09:59:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-10-02T11:45:00Z',
#   'ID': 204328,
#   'UUID': '24CDBFD8-17F5-47CC-BCD8-B9FA3B8834C3',
#   'DataProviderID': 1,
#   'OperatorID': 108,
#   'UsageTypeID': 6,
#   'UsageCost': '€0.5014 / kWh',
#   'AddressInfo': {'ID': 204695,
#    'Title': "McDonald's Parallelweg",
#    'AddressLine1': 'Parallelweg',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '1948 NV',
#    'CountryID': 159,
#    'Latitude': 52.48018978217911,
#    'Longitude': 4.666021248274205,
#    'ContactTelephone1': '+31 (0) 88 363 7991',
#    'RelatedURL': 'https://incharge.vattenfall.nl',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 341395,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 341396,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 342096,
#     'ConnectionTypeID': 1036,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 43.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'GeneralComments': "In front of the McDonald's.",
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-10-02T11:45:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-09-27T10:27:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-09-12T09:24:00Z',
#   'ID': 202500,
#   'UUID': '7D5C607E-3FC4-44C9-8045-01E21AFC6030',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 202867,
#    'Title': 'Nieuwe Kerksplein 16',
#    'AddressLine1': 'Nieuwe Kerksplein 16',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2011 ZT',
#    'CountryID': 159,
#    'Latitude': 52.37749070088256,
#    'Longitude': 4.629442271028097,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 338641,
#     'ConnectionTypeID': 25,
#     'Reference': 'NL-GFX-EPP004022-1',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 20,
#     'Voltage': 230,
#     'PowerKW': 6.0,
#     'CurrentTypeID': 10,
#     'Quantity': 1},
#    {'ID': 338732,
#     'ConnectionTypeID': 0,
#     'Reference': 'NL-GFX-EPP004022-2',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 20,
#     'Voltage': 230,
#     'PowerKW': 6.0,
#     'CurrentTypeID': 10,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-09-12T09:24:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-09-11T11:45:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-09-07T18:21:00Z',
#   'ID': 202121,
#   'UUID': '203B4AFA-7BEC-4216-ADDF-D450D1FA32AD',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 202488,
#    'Title': 'Stephensonstraat 39',
#    'AddressLine1': 'Stephensonstraat 39',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2014 KB',
#    'CountryID': 159,
#    'Latitude': 52.369181828691126,
#    'Longitude': 4.613651889691823,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 337815,
#     'ConnectionTypeID': 25,
#     'Reference': 'NL*GFX*EPP002195*1',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 30,
#     'Voltage': 230,
#     'PowerKW': 6.0,
#     'CurrentTypeID': 10,
#     'Quantity': 1},
#    {'ID': 337816,
#     'ConnectionTypeID': 25,
#     'Reference': 'NL*GFX*EPP002195*2',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 30,
#     'Voltage': 230,
#     'PowerKW': 6.0,
#     'CurrentTypeID': 10,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-09-07T18:21:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-09-07T10:21:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-09-04T11:17:00Z',
#   'ID': 201483,
#   'UUID': 'ABEFE2A5-906F-4FD8-AB17-9DB38A65C6FA',
#   'DataProviderID': 1,
#   'OperatorID': 103,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 201847,
#    'Title': 'Robijnstraat',
#    'AddressLine1': 'Robijnstraat',
#    'Town': 'Leiden',
#    'StateOrProvince': 'South Holland',
#    'Postcode': '2332JL',
#    'CountryID': 159,
#    'Latitude': 52.15618310880117,
#    'Longitude': 4.463912704653239,
#    'ContactTelephone1': '08003745337',
#    'RelatedURL': 'http://www.allego.eu',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 336200,
#     'ConnectionTypeID': 25,
#     'Reference': 'NLALLEGO014481-1',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 32,
#     'Voltage': 480,
#     'PowerKW': 26.6,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-09-04T11:17:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-09-01T20:25:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-09-04T11:18:00Z',
#   'ID': 201482,
#   'UUID': 'A4C6D240-C23B-421C-824C-07FE370651B8',
#   'DataProviderID': 1,
#   'OperatorID': 103,
#   'UsageTypeID': 4,
#   'UsageCost': '.40',
#   'AddressInfo': {'ID': 201846,
#    'Title': '7 Carneoolstraat',
#    'AddressLine1': '7 Carneoolstraat',
#    'Town': 'Leiden',
#    'StateOrProvince': 'South Holland',
#    'Postcode': '2332KA',
#    'CountryID': 159,
#    'Latitude': 52.1546048796059,
#    'Longitude': 4.460548931738117,
#    'ContactTelephone1': '08003745337',
#    'RelatedURL': 'https://www.allego.eu',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 336199,
#     'ConnectionTypeID': 33,
#     'Reference': 'NLALLEGO0059691',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 32,
#     'Voltage': 480,
#     'PowerKW': 26.6,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-09-04T11:18:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-09-01T20:18:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-09-08T15:21:00Z',
#   'ID': 201301,
#   'UUID': 'AF71D9AD-0018-4685-9188-0F44CB854CC4',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 0,
#   'AddressInfo': {'ID': 201664,
#    'Title': 'Stephensonstraat',
#    'AddressLine1': 'Stephensonstraat',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2014 KD',
#    'CountryID': 159,
#    'Latitude': 52.36994650289088,
#    'Longitude': 4.614159016727285,
#    'AccessComments': "Not sure if it's actually public. Single parking spot next to a store, but there's no sign indicating private property.",
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 335771,
#     'ConnectionTypeID': 25,
#     'Reference': '03008537',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 7.4,
#     'CurrentTypeID': 20,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-09-08T15:21:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-08-26T12:12:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-08-28T19:50:00Z',
#   'ID': 201300,
#   'UUID': 'AAA11413-C7AF-4C51-97EA-78522E7287E3',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 201663,
#    'Title': 'Rutherfordstraat',
#    'AddressLine1': 'Rutherfordstraat',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2014 KA',
#    'CountryID': 159,
#    'Latitude': 52.370876207248756,
#    'Longitude': 4.614198948038165,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 335770,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-08-28T19:50:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-08-26T12:09:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-08-12T06:28:00Z',
#   'ID': 195040,
#   'UUID': '7694A444-92E2-4AF8-8FEB-ED98004AA89D',
#   'DataProviderID': 1,
#   'OperatorID': 3299,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 195399,
#    'Title': 'IONITY Mienscheer',
#    'AddressLine1': 'Rijksweg A2 7, Niebert',
#    'Town': 'Niebert',
#    'StateOrProvince': 'Groningen',
#    'Postcode': '9365 TK',
#    'CountryID': 159,
#    'Latitude': 53.161647,
#    'Longitude': 6.292686,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 317842,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 350.0,
#     'CurrentTypeID': 30,
#     'Quantity': 3}],
#   'NumberOfPoints': 3,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-08-12T06:28:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-08-11T23:09:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-08-08T09:47:00Z',
#   'ID': 194587,
#   'UUID': '48967583-C8DC-4C72-9732-DC290E0356F2',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 1,
#   'UsageCost': '€0.27 per session, €0.31 per kWh, free parking',
#   'AddressInfo': {'ID': 194946,
#    'Title': 'Pijlslaan',
#    'AddressLine1': 'Pijlslaan',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2014 TL',
#    'CountryID': 159,
#    'Latitude': 52.372003720140015,
#    'Longitude': 4.611520743119058,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 317243,
#     'ConnectionTypeID': 25,
#     'Reference': 'NL-GFX-EPP004181-1',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 317244,
#     'ConnectionTypeID': 25,
#     'Reference': 'NL-GFX-EPP004181-2',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-08-08T09:47:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-08-07T10:45:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-10-10T11:20:00Z',
#   'ID': 194583,
#   'UUID': 'E68323DF-A400-48DA-8C8C-18CB43D7628D',
#   'DataProviderID': 1,
#   'OperatorID': 74,
#   'UsageCost': 'https://fastnedcharging.com/nl/tarieven',
#   'AddressInfo': {'ID': 194942,
#    'Title': 'Twaalfmat',
#    'AddressLine1': 'Twaalfmat',
#    'Town': 'Heemskerk',
#    'Postcode': '1967 PV',
#    'CountryID': 159,
#    'Latitude': 52.500278047265056,
#    'Longitude': 4.702634557778197,
#    'ContactTelephone1': '020-7055300',
#    'ContactEmail': 'support@fastned.nl',
#    'RelatedURL': 'http://fastned.nl',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 317231,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 125.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2},
#    {'ID': 317232,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1}],
#   'NumberOfPoints': 2,
#   'GeneralComments': '2 stations have only CCS, 2 have CCS and CHAdeMO',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-10-10T11:20:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-08-06T23:20:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-08-09T21:07:00Z',
#   'ID': 194582,
#   'UUID': 'BA03A42F-FDA0-4BD3-A9D3-518DBBBF3F2A',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 1,
#   'UsageCost': '€0.31 per kWh',
#   'AddressInfo': {'ID': 194941,
#    'Title': 'Lorentzkade',
#    'AddressLine1': 'Lorentzkade',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2014 CE',
#    'CountryID': 159,
#    'Latitude': 52.373997763985926,
#    'Longitude': 4.611189696895622,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 317230,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-08-09T21:07:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-08-06T23:03:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-08-05T21:57:00Z',
#   'ID': 194570,
#   'UUID': 'FF2CFDAE-0FE3-4387-91E5-A6A1E1F41B5F',
#   'DataProviderID': 1,
#   'OperatorID': 103,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 194929,
#    'Title': 'Botnische golf',
#    'AddressLine1': 'Botnische golf',
#    'Town': 'Woerden',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3446XW',
#    'CountryID': 159,
#    'Latitude': 52.07745826113799,
#    'Longitude': 4.904246265408801,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 317171,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 317172,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 317173,
#     'ConnectionTypeID': 1036,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 43.0,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-08-05T21:57:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-08-05T21:57:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-08-03T08:29:00Z',
#   'ID': 194366,
#   'UUID': 'BEE8C11F-8043-4A73-A0BA-9A93A4EEDE74',
#   'DataProviderID': 1,
#   'OperatorID': 3299,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 194725,
#    'Title': 'IONITY Sandelingen Oost',
#    'AddressLine1': 'A16 highway2952 AD ',
#    'Town': 'Hendrik-Ido-Ambacht',
#    'Postcode': '2952 AD',
#    'CountryID': 159,
#    'Latitude': 24.0,
#    'Longitude': 4.620008,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 316698,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 350.0,
#     'CurrentTypeID': 30,
#     'Quantity': 4}],
#   'NumberOfPoints': 4,
#   'StatusTypeID': 210,
#   'DateLastStatusUpdate': '2022-08-03T08:29:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-07-28T22:31:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-07-29T15:55:00Z',
#   'ID': 194365,
#   'UUID': 'D24CBF8C-963D-4B29-9C6A-5ACAE96E61D8',
#   'DataProviderID': 1,
#   'OperatorID': 3299,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 194724,
#    'Title': 'IONITY Sandelingen Oost',
#    'AddressLine1': 'A16 highway2952 AD ',
#    'Town': 'Hendrik-Ido-Ambacht',
#    'Postcode': '2952 AD',
#    'CountryID': 159,
#    'Latitude': 51.836003,
#    'Longitude': 4.620008,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 316697,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 350.0,
#     'CurrentTypeID': 30,
#     'Quantity': 4}],
#   'NumberOfPoints': 4,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-07-29T15:55:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-07-28T22:20:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-07-25T08:55:00Z',
#   'ID': 194305,
#   'UUID': 'CF5EB74E-1022-486F-997C-FC07F0AFA19E',
#   'DataProviderID': 1,
#   'OperatorID': 3387,
#   'UsageTypeID': 1,
#   'UsageCost': ' € 0.36/kWh',
#   'AddressInfo': {'ID': 194664,
#    'Title': 'Boerderijcamping Zuiderhoeve',
#    'AddressLine1': 'Dishoekseweg 28A',
#    'Town': 'Koudekerke',
#    'StateOrProvince': 'Zeeland',
#    'Postcode': '4371 NH',
#    'CountryID': 159,
#    'Latitude': 51.47525081439318,
#    'Longitude': 3.541423812603057,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 316548,
#     'ConnectionTypeID': 25,
#     'Reference': 'E44374',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 32,
#     'Voltage': 400,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 316553,
#     'ConnectionTypeID': 25,
#     'Reference': 'E44375',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 32,
#     'Voltage': 400,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-07-25T08:55:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-07-24T18:20:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-01-17T22:54:00Z',
#   'ID': 194248,
#   'UUID': '846843E5-E307-4981-B778-2CE70709625B',
#   'DataProviderID': 1,
#   'OperatorID': 3504,
#   'UsageTypeID': 1,
#   'UsageCost': '€0.71/kWh',
#   'AddressInfo': {'ID': 194607,
#    'Title': 'LEAP24 Fast Charge Station',
#    'AddressLine1': '1 Industrieweg',
#    'Town': 'Sittard-Geleen',
#    'StateOrProvince': 'Limburg',
#    'Postcode': '6163AH',
#    'CountryID': 159,
#    'Latitude': 50.981218592935164,
#    'Longitude': 5.826535347417348,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 316427,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 250,
#     'PowerKW': 120.0,
#     'CurrentTypeID': 30,
#     'Quantity': 6}],
#   'NumberOfPoints': 6,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-01-17T22:54:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-07-21T13:16:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-08-25T14:53:00Z',
#   'ID': 194169,
#   'UUID': '104A2B3E-F48D-452C-A1B8-E50B118618CD',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 4,
#   'UsageCost': '€0.31 per kWh',
#   'AddressInfo': {'ID': 194528,
#    'Title': 'Lorentzkade 192',
#    'AddressLine1': 'Lorentzkade 192',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2014 CE',
#    'CountryID': 159,
#    'Latitude': 52.37385749804912,
#    'Longitude': 4.611194772672775,
#    'ContactTelephone1': '+31 30 410 0887',
#    'ContactEmail': 'elektrischrijden@totalenergies.com',
#    'RelatedURL': 'https://services.totalenergies.nl',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 316275,
#     'ConnectionTypeID': 25,
#     'Reference': 'NL*GFX*EPP001549*1',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1},
#    {'ID': 316298,
#     'ConnectionTypeID': 25,
#     'Reference': 'NL*GFX*EPP001549*2',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-08-25T14:53:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-07-17T07:48:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-07-14T15:29:00Z',
#   'ID': 194027,
#   'UUID': 'FC60351C-7EEE-445F-A6D4-914C9FE1386B',
#   'DataProviderID': 1,
#   'OperatorID': 23,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 194386,
#    'Title': 'Slakweg',
#    'AddressLine1': 'Slakweg',
#    'Town': 'Maastricht',
#    'StateOrProvince': 'Limburg',
#    'Postcode': '6228',
#    'CountryID': 159,
#    'Latitude': 50.81612219964967,
#    'Longitude': 5.725457854811339,
#    'DistanceUnit': 0},
#   'Connections': [],
#   'NumberOfPoints': 24,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-07-14T15:29:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-07-11T15:26:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-07-14T12:49:00Z',
#   'ID': 193988,
#   'UUID': '9E012E0D-65F5-4E82-8BD5-BC7B52D764B1',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 6,
#   'AddressInfo': {'ID': 194347,
#    'Title': 'Klappermanstraat',
#    'AddressLine1': 'Klappermanstraat',
#    'StateOrProvince': 'North Brabant',
#    'Postcode': '5554EM',
#    'CountryID': 159,
#    'Latitude': 51.3478214,
#    'Longitude': 5.4650453,
#    'ContactTelephone1': '7714981255',
#    'ContactEmail': 'mlarchbank@hotmail.com',
#    'DistanceUnit': 0},
#   'Connections': [],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-07-14T12:49:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-07-11T12:44:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2023-01-17T22:54:00Z',
#   'ID': 193861,
#   'UUID': '8F103F63-FC6E-4CA4-9CBB-F9C29B2276A6',
#   'DataProviderID': 1,
#   'OperatorID': 3504,
#   'UsageTypeID': 1,
#   'UsageCost': '€0.71/kWh incl. VAT',
#   'AddressInfo': {'ID': 194220,
#    'Title': 'Reyerdijk LEAP24 Snellaadstation',
#    'AddressLine1': 'Reyerdijk 110',
#    'Town': 'Rotterdam',
#    'StateOrProvince': 'Zuid Holland',
#    'Postcode': '3079',
#    'CountryID': 159,
#    'Latitude': 51.88148057397515,
#    'Longitude': 4.542689376008184,
#    'RelatedURL': 'http://leap24.eu',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 315642,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 250,
#     'Voltage': 1000,
#     'PowerKW': 120.0,
#     'CurrentTypeID': 30,
#     'Quantity': 7}],
#   'NumberOfPoints': 7,
#   'GeneralComments': 'Vans fit on parking bays',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2023-01-17T22:54:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-07-04T12:13:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-06-06T12:10:00Z',
#   'ID': 193379,
#   'UUID': 'F5C03586-4AB4-455E-9629-3E7C08BAA86D',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 193738,
#    'Title': '31 Hoofdstraat',
#    'AddressLine1': '31 Hoofdstraat',
#    'Town': 'Gorssel',
#    'StateOrProvince': 'Gelderland',
#    'Postcode': '7213CP',
#    'CountryID': 159,
#    'Latitude': 52.1982121,
#    'Longitude': 6.199734,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 314565,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 314566,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'GeneralComments': 'Near church Gorssel',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-06-06T12:10:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-06-06T08:58:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-06-06T08:01:00Z',
#   'ID': 193375,
#   'UUID': 'AEC834D6-D363-4E12-B719-4FAE1C6E7B1B',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'UsageCost': '0,69',
#   'AddressInfo': {'ID': 193734,
#    'Title': 'Shell Tatelaar Didam',
#    'AddressLine1': 'Tatelaarweg 21',
#    'Town': 'Didam',
#    'StateOrProvince': 'Gelderland',
#    'Postcode': '6941RB',
#    'CountryID': 159,
#    'Latitude': 51.93702950683783,
#    'Longitude': 6.105900472739108,
#    'ContactTelephone1': '0031316294322',
#    'ContactTelephone2': '0031316294322',
#    'RelatedURL': 'http://ww.tatelaar.nl',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 314558,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 250,
#     'PowerKW': 150.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'GeneralComments': 'Shell tatelaar cafe',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-06-06T08:01:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-06-05T18:50:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2022-06-06T08:52:00Z',
#   'ID': 193365,
#   'UUID': '0F0ABCDC-93A6-46DE-A4A1-FAA0D5423ED8',
#   'DataProviderID': 1,
#   'OperatorID': 47,
#   'UsageTypeID': 1,
#   'UsageCost': '€ 0.35/kWh',
# ...
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:43:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190734,
#   'UUID': '017EF5B4-F08A-4930-9B20-88172B943555',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191093,
#    'Title': '22 Johan Willem Frisostraat',
#    'AddressLine1': '22 Johan Willem Frisostraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583JT',
#    'CountryID': 159,
#    'Latitude': 52.091211258387716,
#    'Longitude': 5.14362166824526,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309328,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:43:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190733,
#   'UUID': '53896F5E-DB3D-4405-A036-8693C3417C39',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191092,
#    'Title': 'Johan Willem Frisostraat',
#    'AddressLine1': 'Johan Willem Frisostraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583JR',
#    'CountryID': 159,
#    'Latitude': 52.09091765343223,
#    'Longitude': 5.1426455651408105,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309327,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:43:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190732,
#   'UUID': '05963D16-C0FA-4E91-A905-E2D25F0EDC7A',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191091,
#    'Title': 'Stolberglaan',
#    'AddressLine1': 'Stolberglaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583HN',
#    'CountryID': 159,
#    'Latitude': 52.09156927028508,
#    'Longitude': 5.142013335418824,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309326, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:40:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190731,
#   'UUID': 'B1AB24C7-FC0A-43A9-B4BC-DBB54388A21D',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191090,
#    'Title': 'Emmalaan',
#    'AddressLine1': 'Emmalaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581HM',
#    'CountryID': 159,
#    'Latitude': 52.09334789225565,
#    'Longitude': 5.13998540702346,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309325,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:38:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190730,
#   'UUID': '5C1A2EE6-38FF-4268-B1F5-79BD6F6C1B8A',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191089,
#    'Title': '74 Wolter Heukelslaan',
#    'AddressLine1': '74 Wolter Heukelslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581SV',
#    'CountryID': 159,
#    'Latitude': 52.094065878017204,
#    'Longitude': 5.138216938305618,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309324,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:37:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190729,
#   'UUID': 'C4F150B5-BABA-45F0-9863-7CC2C851F9CE',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191088,
#    'Title': '70 Wolter Heukelslaan',
#    'AddressLine1': '70 Wolter Heukelslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581SV',
#    'CountryID': 159,
#    'Latitude': 52.093662668099284,
#    'Longitude': 5.138263700923744,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309323,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:37:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190728,
#   'UUID': '2FE27AE1-0EA5-4CA8-9DE7-CBEACAA12582',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191087,
#    'Title': '65A-BS Wolter Heukelslaan',
#    'AddressLine1': '65A-BS Wolter Heukelslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581SV',
#    'CountryID': 159,
#    'Latitude': 52.09299309878932,
#    'Longitude': 5.137815118952972,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309322,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:36:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190727,
#   'UUID': '9EB25934-6F8B-4C91-855D-0055B107AEB2',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191086,
#    'Title': 'Zonnehof',
#    'AddressLine1': 'Zonnehof',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581MZ',
#    'CountryID': 159,
#    'Latitude': 52.08557265458322,
#    'Longitude': 5.134593090747785,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309321,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:35:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190726,
#   'UUID': '66936221-B90B-4F8E-8551-5014BBD34E1F',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191085,
#    'Title': '62 Homeruslaan',
#    'AddressLine1': '62 Homeruslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581MJ',
#    'CountryID': 159,
#    'Latitude': 52.08539424128722,
#    'Longitude': 5.1366493877505945,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309320,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:35:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190725,
#   'UUID': '77460107-E1C2-41A5-9587-C91AC848D36B',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191084,
#    'Title': 'Koningslaan',
#    'AddressLine1': 'Koningslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583GV',
#    'CountryID': 159,
#    'Latitude': 52.08549713969251,
#    'Longitude': 5.139713048908561,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309319,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:34:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190724,
#   'UUID': '29E0E4EA-04A9-48EF-9EA6-004060C6DEA9',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191083,
#    'Title': 'Wagendwarsstraat',
#    'AddressLine1': 'Wagendwarsstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581WH',
#    'CountryID': 159,
#    'Latitude': 52.09005478679455,
#    'Longitude': 5.133734557582329,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309318,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:33:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190723,
#   'UUID': 'C8E3FE05-1B7D-4462-85AB-97E58EEE8F0F',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191082,
#    'Title': '15 Bloesemstraat',
#    'AddressLine1': '15 Bloesemstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581XA',
#    'CountryID': 159,
#    'Latitude': 52.08818594300041,
#    'Longitude': 5.133346335065994,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309317,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:32:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190722,
#   'UUID': 'A3D2C5D0-A3FF-4BA2-AAA1-3926D20E7214',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191081,
#    'Title': 'Minervaplein',
#    'AddressLine1': 'Minervaplein',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581XP',
#    'CountryID': 159,
#    'Latitude': 52.086329944695024,
#    'Longitude': 5.13538062577652,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309316,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:31:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190721,
#   'UUID': 'ED61E389-9A4F-4894-8F0C-44713020BEB6',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191080,
#    'Title': '80 Bankstraat',
#    'AddressLine1': '80 Bankstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581LP',
#    'CountryID': 159,
#    'Latitude': 52.08692819056603,
#    'Longitude': 5.135704882230243,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309315,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:30:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190720,
#   'UUID': '43C7C227-2BA6-48BD-980D-00345CC6CB3A',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'AddressInfo': {'ID': 191079,
#    'Title': 'Willem de Zwijgerstraat',
#    'AddressLine1': 'Willem de Zwijgerstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583HA',
#    'CountryID': 159,
#    'Latitude': 52.0872231173976,
#    'Longitude': 5.14253424432502,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309314, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:27:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190719,
#   'UUID': '0596ACEF-1774-4185-B2EA-324F7B3CFED8',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'UsageCost': '0,36 per kWh',
#   'AddressInfo': {'ID': 191078,
#    'Title': 'Dillenburgstraat',
#    'AddressLine1': 'Dillenburgstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583VA',
#    'CountryID': 159,
#    'Latitude': 52.08916478875773,
#    'Longitude': 5.142193386030044,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309313, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:23:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:27:00Z',
#   'ID': 190718,
#   'UUID': '1BEBBF07-62A2-4012-A391-0B4680D226FB',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'UsageCost': '0,36 per kWh',
#   'AddressInfo': {'ID': 191077,
#    'Title': 'Van Alphenplein',
#    'AddressLine1': 'Van Alphenplein',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581JE',
#    'CountryID': 159,
#    'Latitude': 52.091717725238425,
#    'Longitude': 5.138035548936045,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309312, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:22:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-12-19T21:27:00Z',
#   'ID': 190717,
#   'UUID': '4AAA04A5-D7D1-4C65-94B1-A2308FC480C2',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'UsageCost': '0,36 per kWh',
#   'AddressInfo': {'ID': 191076,
#    'Title': 'Wolter Heukelslaan',
#    'AddressLine1': 'Wolter Heukelslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581SR',
#    'CountryID': 159,
#    'Latitude': 52.091365709776454,
#    'Longitude': 5.13593364135636,
#    'DistanceUnit': 0},
#   'Connections': [],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:20:00Z',
#   'SubmissionStatusTypeID': 200}]

# %%
response.json()
# Out:
# [{'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-04-06T22:19:00Z',
#   'ID': 192439,
#   'UUID': 'BC88010C-296D-48B1-A222-D959B847C318',
#   'DataProviderID': 1,
#   'OperatorID': 103,
#   'UsageTypeID': 1,
#   'UsageCost': '€0,39 kW/h',
#   'AddressInfo': {'ID': 192798,
#    'Title': 'Allego Zwaluwstraat 15',
#    'AddressLine1': 'Zwaluwstraat 15',
#    'Town': 'Maassluis',
#    'StateOrProvince': 'Zuid-Holland',
#    'Postcode': '3145NG',
#    'CountryID': 159,
#    'Latitude': 51.93141936867795,
#    'Longitude': 4.238358198599883,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 312635,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-04-06T22:19:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-04-03T22:14:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-04-06T21:49:00Z',
#   'ID': 192438,
#   'UUID': 'F87CAFB4-D029-4753-9707-E292ED9D6278',
#   'DataProviderID': 1,
#   'OperatorID': 74,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 192797,
#    'Title': 'Fastned Peulwijk-Oost',
#    'AddressLine1': 'Rijksweg A4',
#    'Town': 'Den Hoorn',
#    'StateOrProvince': 'Zuid-Holland',
#    'Postcode': '2635BW',
#    'CountryID': 159,
#    'Latitude': 52.00917951726262,
#    'Longitude': 4.312016522762235,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 312634,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 300.0,
#     'CurrentTypeID': 30,
#     'Quantity': 4}],
#   'NumberOfPoints': 4,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-04-06T21:49:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-04-03T21:46:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-04-06T21:44:00Z',
#   'ID': 192437,
#   'UUID': '74191846-9132-4229-9F74-E5749C3F2D25',
#   'DataProviderID': 1,
#   'OperatorID': 74,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 192796,
#    'Title': 'Fastned Hogenhoorn',
#    'AddressLine1': 'Hogenhoorn 3',
#    'Town': 'Den Hoorn',
#    'StateOrProvince': 'Zuid-Holland',
#    'Postcode': '2635 BZ',
#    'CountryID': 159,
#    'Latitude': 52.01195360295989,
#    'Longitude': 4.315466804741391,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 312632,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 300.0,
#     'CurrentTypeID': 30,
#     'Quantity': 10},
#    {'ID': 312633,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 10,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-04-06T21:44:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-04-03T21:40:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-04-02T04:10:00Z',
#   'ID': 192339,
#   'UUID': '7BC34EE6-5499-4F51-A08A-BC3164D47B35',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 192698,
#    'Title': 'van Eerbeeklaan 2',
#    'AddressLine1': 'van Eerbeeklaan 2',
#    'Town': 'Uithoorn',
#    'StateOrProvince': 'Noord-Holland',
#    'Postcode': '1422GG',
#    'CountryID': 159,
#    'Latitude': 52.24550215072222,
#    'Longitude': 4.829777348453177,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 312483,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1,
#     'Comments': 'fixed cable'}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-04-02T04:10:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-03-30T13:39:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-02-21T22:09:00Z',
#   'ID': 191685,
#   'UUID': '006EEA5F-8258-4179-AC33-4EB27C157A78',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 192044,
#    'Title': 'Platanenlaan 12',
#    'AddressLine1': 'Platanenlaan 12',
#    'Town': 'Nederhorst den Berg',
#    'StateOrProvince': 'Noord-Holland',
#    'Postcode': '1394 JR',
#    'CountryID': 159,
#    'Latitude': 52.25009579068714,
#    'Longitude': 5.046898739448807,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 311293,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-02-21T22:09:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-02-21T09:15:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-02-22T08:20:00Z',
#   'ID': 191683,
#   'UUID': 'F9A89AA7-6DF3-4206-9E8B-8C67AA1090AD',
#   'DataProviderID': 1,
#   'OperatorID': 45,
#   'UsageTypeID': 6,
#   'AddressInfo': {'ID': 192042,
#    'Title': '5 Goeseelsstraat',
#    'AddressLine1': '5 Goeseelsstraat',
#    'Town': 'Breda',
#    'StateOrProvince': 'North Brabant',
#    'Postcode': '4817MV',
#    'CountryID': 159,
#    'Latitude': 51.59475608450231,
#    'Longitude': 4.797436275629025,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 311291,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 5}],
#   'NumberOfPoints': 5,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-02-22T08:20:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-02-20T22:53:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2022-02-07T08:54:00Z',
#   'ID': 191365,
#   'UUID': 'E7FF6AE2-F8C2-4F06-9676-810854CA488F',
#   'DataProviderID': 1,
#   'OperatorID': 38,
#   'UsageTypeID': 1,
#   'UsageCost': '0',
#   'AddressInfo': {'ID': 191724,
#    'Title': 'Lidl - Woerden',
#    'AddressLine1': 'Lepellaan 1',
#    'Town': 'Woerden',
#    'StateOrProvince': 'UTRECHT',
#    'CountryID': 159,
#    'Latitude': 52.0815342436093,
#    'Longitude': 4.8763468008691575,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 310649,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 120,
#     'Voltage': 400,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 310650,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'Amps': 120,
#     'Voltage': 400,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 310651,
#     'ConnectionTypeID': 1036,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 43.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1,
#     'Comments': ''}],
#   'NumberOfPoints': 2,
#   'GeneralComments': 'FREE for Shoppers, 30 minutes. ',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2022-02-07T08:54:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2022-02-07T08:54:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-29T14:57:00Z',
#   'ID': 190860,
#   'UUID': '29C2D400-F957-4E36-8069-B4416ABDBA3F',
#   'DataProviderID': 1,
#   'OperatorID': 103,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191219,
#    'Title': 'Martinetsingel',
#    'AddressLine1': 'Martinetsingel',
#    'Town': 'Zutphen',
#    'StateOrProvince': 'Gelderland',
#    'Postcode': '7201DZ',
#    'CountryID': 159,
#    'Latitude': 52.139127107971944,
#    'Longitude': 6.198663242153316,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309557,
#     'ConnectionTypeID': 0,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-29T14:57:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-28T19:07:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-29T14:58:00Z',
#   'ID': 190859,
#   'UUID': 'CF7FA27E-7D98-42F0-A4E6-B870D890109A',
#   'DataProviderID': 1,
#   'OperatorID': 3387,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191218,
#    'Title': '45 Zijlvest',
#    'AddressLine1': 'Zijlvest 45',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2011VB',
#    'CountryID': 159,
#    'Latitude': 52.38162773568132,
#    'Longitude': 4.629299343716525,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309556,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 32,
#     'Voltage': 400,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 12}],
#   'NumberOfPoints': 12,
#   'GeneralComments': 'Inside parking garage',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-29T14:58:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-28T19:05:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-29T15:01:00Z',
#   'ID': 190858,
#   'UUID': '0691509F-69E8-4F0B-B6DD-E2B81CAC1E6A',
#   'DataProviderID': 1,
#   'OperatorID': 73,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191217,
#    'Title': 'Johan de Wittstraat 3',
#    'AddressLine1': 'Johan de Wittstraat 3',
#    'Town': 'Wassenaar',
#    'StateOrProvince': 'South Holland',
#    'Postcode': '2242LB',
#    'CountryID': 159,
#    'Latitude': 52.142832881845806,
#    'Longitude': 4.396562071018252,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309555,
#     'ConnectionTypeID': 25,
#     'Reference': 'EVB-P2004138',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-29T15:01:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-28T19:00:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-29T15:03:00Z',
#   'ID': 190857,
#   'UUID': '47493C76-B424-4172-8489-C5C5EF1A43CC',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191216,
#    'Title': 'Koorstraat',
#    'AddressLine1': 'Koorstraat',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2012GP',
#    'CountryID': 159,
#    'Latitude': 52.37612866380192,
#    'Longitude': 4.6232540415333006,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309554,
#     'ConnectionTypeID': 25,
#     'Reference': '05b16ccf-d8f8-44fe-8efb-7915f8750795',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-29T15:03:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-28T18:58:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-29T15:18:00Z',
#   'ID': 190856,
#   'UUID': '836DA649-A065-4188-A7ED-08A3853D970D',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191215,
#    'Title': 'Westerstraat',
#    'AddressLine1': 'Westerstraat',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2013PN',
#    'CountryID': 159,
#    'Latitude': 52.38002741031801,
#    'Longitude': 4.617947970403748,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309553,
#     'ConnectionTypeID': 25,
#     'Reference': '38dfb187-8c7e-4996-9ded-b67adf8c7524',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 32,
#     'Voltage': 400,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-29T15:18:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-28T18:56:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-29T15:24:00Z',
#   'ID': 190855,
#   'UUID': '2B325EEA-7B28-4193-92AF-143085972AE1',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191214,
#    'Title': 'Leidseplein 5',
#    'AddressLine1': 'Leidseplein 5',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2013PV',
#    'CountryID': 159,
#    'Latitude': 52.37936273410284,
#    'Longitude': 4.624896923061669,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309552,
#     'ConnectionTypeID': 25,
#     'Reference': '6a4ec87f-a6d6-400a-aece-4e7ec64beb8f',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-29T15:24:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-28T18:55:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-29T15:25:00Z',
#   'ID': 190854,
#   'UUID': '0124B77E-45A9-4C32-AE49-26E655C05CF9',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191213,
#    'Title': 'Leidsevaart',
#    'AddressLine1': 'Leidsevaart',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2013HC',
#    'CountryID': 159,
#    'Latitude': 52.379180705342606,
#    'Longitude': 4.6255161386943655,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309551,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-29T15:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-28T18:53:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-29T15:26:00Z',
#   'ID': 190853,
#   'UUID': '97FE51C3-D124-4890-801C-62EA4524817B',
#   'DataProviderID': 1,
#   'OperatorID': 63,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191212,
#    'Title': 'Emmaplein 44',
#    'AddressLine1': 'Emmaplein 44',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'North Holland',
#    'Postcode': '2014XK',
#    'CountryID': 159,
#    'Latitude': 52.37615398667208,
#    'Longitude': 4.620922324279832,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309550,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-29T15:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-28T18:51:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-31T18:54:00Z',
#   'ID': 190852,
#   'UUID': '53997AA1-7C15-4CAA-832F-0919D759D4AA',
#   'DataProviderID': 1,
#   'OperatorID': 3447,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 191211,
#    'Title': 'Oranjeboomstraat 192',
#    'AddressLine1': 'Oranjeboomstraat 192',
#    'Town': 'Haarlem',
#    'StateOrProvince': 'Noord-Holland',
#    'Postcode': '2013WD',
#    'CountryID': 159,
#    'Latitude': 52.3784293311314,
#    'Longitude': 4.621668786092414,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309549,
#     'ConnectionTypeID': 0,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 11.0}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-31T18:54:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-28T18:46:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-25T14:46:00Z',
#   'ID': 190800,
#   'UUID': 'BD05C762-CA64-4F49-B045-784B48AD09E4',
#   'DataProviderID': 1,
#   'OperatorID': 69,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 191159,
#    'Title': 'Kloosterhof 1 Malden',
#    'AddressLine1': 'Kloosterhof 1',
#    'Town': 'Heumen',
#    'StateOrProvince': 'Gelderland',
#    'Postcode': '6581WL',
#    'CountryID': 159,
#    'Latitude': 51.78351485299547,
#    'Longitude': 5.853117655653705,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309440,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2},
#    {'ID': 309441,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 7.0,
#     'CurrentTypeID': 10,
#     'Quantity': 2}],
#   'NumberOfPoints': 4,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-25T14:46:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-25T14:46:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-25T09:43:00Z',
#   'ID': 190786,
#   'UUID': 'B7964B4D-F380-44FB-86D2-EF1024DE0382',
#   'DataProviderID': 1,
#   'OperatorID': 103,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191145,
#    'Title': ' Allego (NL) - 2 Beelen - Tolbert',
#    'AddressLine1': 'Beelen 2',
#    'Town': 'Tolbert',
#    'StateOrProvince': 'Groningen',
#    'Postcode': '9356 CA',
#    'CountryID': 159,
#    'Latitude': 53.16617235219772,
#    'Longitude': 6.365452206876483,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309412,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-25T09:43:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-23T12:58:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:24:00Z',
#   'ID': 190742,
#   'UUID': '69729E32-FF5F-448D-938E-8A46CA11E8A2',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191101,
#    'Title': '1A Maliestraat',
#    'AddressLine1': '1A Maliestraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581SH',
#    'CountryID': 159,
#    'Latitude': 52.09439885061656,
#    'Longitude': 5.13682600351558,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309336,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:24:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:50:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:24:00Z',
#   'ID': 190741,
#   'UUID': 'C6E392CB-8BA2-4D1C-9F5D-C42D5C139064',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191100,
#    'Title': 'Partou Kinderopvang',
#    'AddressLine1': 'Partou Kinderopvang',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581ET',
#    'CountryID': 159,
#    'Latitude': 52.09460183680176,
#    'Longitude': 5.137383584372742,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309335,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:24:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:50:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:24:00Z',
#   'ID': 190740,
#   'UUID': '85DD74F8-33E0-4E40-99CD-D0039A7B9C7B',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191099,
#    'Title': '2 Johan de Wittstraat',
#    'AddressLine1': '2 Johan de Wittstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581XX',
#    'CountryID': 159,
#    'Latitude': 52.08747062866928,
#    'Longitude': 5.1294540610476815,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309334,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:24:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:48:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190739,
#   'UUID': '399A56CB-BF57-4BE3-BE25-8322719D9A0E',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191098,
#    'Title': '50 Maliesingel',
#    'AddressLine1': '50 Maliesingel',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581BN',
#    'CountryID': 159,
#    'Latitude': 52.08681383473356,
#    'Longitude': 5.12965218031195,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309333,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:48:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190738,
#   'UUID': '400F9DB4-48C8-4D21-A366-349E9F5E73C6',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191097,
#    'Title': '146-BS Frederik Hendrikstraat',
#    'AddressLine1': '146-BS Frederik Hendrikstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583VS',
#    'CountryID': 159,
#    'Latitude': 52.08753185131545,
#    'Longitude': 5.144907961435706,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309332,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:45:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190737,
#   'UUID': '5807B867-D0B9-4905-BD95-89CD52639D44',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191096,
#    'Title': 'Frederik Hendrikstraat',
#    'AddressLine1': 'Frederik Hendrikstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583VN',
#    'CountryID': 159,
#    'Latitude': 52.0893326912462,
#    'Longitude': 5.144997951445703,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309331,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:44:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190736,
#   'UUID': 'C8C7BD55-7825-4B4C-9025-71387A9A4866',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191095,
#    'Title': 'Dillenburgstraat',
#    'AddressLine1': 'Dillenburgstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583VC',
#    'CountryID': 159,
#    'Latitude': 52.08933791435135,
#    'Longitude': 5.144052165853964,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309330,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:44:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190735,
#   'UUID': 'B2732172-F1C2-4135-836D-8F962CCEF7FD',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191094,
#    'Title': 'Frederik Hendrikstraat',
#    'AddressLine1': 'Frederik Hendrikstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583VV',
#    'CountryID': 159,
#    'Latitude': 52.09133977918398,
#    'Longitude': 5.144411430434616,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309329,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:43:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190734,
#   'UUID': '017EF5B4-F08A-4930-9B20-88172B943555',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191093,
#    'Title': '22 Johan Willem Frisostraat',
#    'AddressLine1': '22 Johan Willem Frisostraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583JT',
#    'CountryID': 159,
#    'Latitude': 52.091211258387716,
#    'Longitude': 5.14362166824526,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309328,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:43:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190733,
#   'UUID': '53896F5E-DB3D-4405-A036-8693C3417C39',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191092,
#    'Title': 'Johan Willem Frisostraat',
#    'AddressLine1': 'Johan Willem Frisostraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583JR',
#    'CountryID': 159,
#    'Latitude': 52.09091765343223,
#    'Longitude': 5.1426455651408105,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309327,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:43:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190732,
#   'UUID': '05963D16-C0FA-4E91-A905-E2D25F0EDC7A',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191091,
#    'Title': 'Stolberglaan',
#    'AddressLine1': 'Stolberglaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583HN',
#    'CountryID': 159,
#    'Latitude': 52.09156927028508,
#    'Longitude': 5.142013335418824,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309326, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:40:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:25:00Z',
#   'ID': 190731,
#   'UUID': 'B1AB24C7-FC0A-43A9-B4BC-DBB54388A21D',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191090,
#    'Title': 'Emmalaan',
#    'AddressLine1': 'Emmalaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581HM',
#    'CountryID': 159,
#    'Latitude': 52.09334789225565,
#    'Longitude': 5.13998540702346,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309325,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:25:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:38:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190730,
#   'UUID': '5C1A2EE6-38FF-4268-B1F5-79BD6F6C1B8A',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191089,
#    'Title': '74 Wolter Heukelslaan',
#    'AddressLine1': '74 Wolter Heukelslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581SV',
#    'CountryID': 159,
#    'Latitude': 52.094065878017204,
#    'Longitude': 5.138216938305618,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309324,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:37:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190729,
#   'UUID': 'C4F150B5-BABA-45F0-9863-7CC2C851F9CE',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191088,
#    'Title': '70 Wolter Heukelslaan',
#    'AddressLine1': '70 Wolter Heukelslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581SV',
#    'CountryID': 159,
#    'Latitude': 52.093662668099284,
#    'Longitude': 5.138263700923744,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309323,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:37:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190728,
#   'UUID': '2FE27AE1-0EA5-4CA8-9DE7-CBEACAA12582',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191087,
#    'Title': '65A-BS Wolter Heukelslaan',
#    'AddressLine1': '65A-BS Wolter Heukelslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581SV',
#    'CountryID': 159,
#    'Latitude': 52.09299309878932,
#    'Longitude': 5.137815118952972,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309322,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:36:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190727,
#   'UUID': '9EB25934-6F8B-4C91-855D-0055B107AEB2',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191086,
#    'Title': 'Zonnehof',
#    'AddressLine1': 'Zonnehof',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581MZ',
#    'CountryID': 159,
#    'Latitude': 52.08557265458322,
#    'Longitude': 5.134593090747785,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309321,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:35:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190726,
#   'UUID': '66936221-B90B-4F8E-8551-5014BBD34E1F',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191085,
#    'Title': '62 Homeruslaan',
#    'AddressLine1': '62 Homeruslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581MJ',
#    'CountryID': 159,
#    'Latitude': 52.08539424128722,
#    'Longitude': 5.1366493877505945,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309320,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:35:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190725,
#   'UUID': '77460107-E1C2-41A5-9587-C91AC848D36B',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191084,
#    'Title': 'Koningslaan',
#    'AddressLine1': 'Koningslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583GV',
#    'CountryID': 159,
#    'Latitude': 52.08549713969251,
#    'Longitude': 5.139713048908561,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309319,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:34:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190724,
#   'UUID': '29E0E4EA-04A9-48EF-9EA6-004060C6DEA9',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191083,
#    'Title': 'Wagendwarsstraat',
#    'AddressLine1': 'Wagendwarsstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581WH',
#    'CountryID': 159,
#    'Latitude': 52.09005478679455,
#    'Longitude': 5.133734557582329,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309318,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:33:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190723,
#   'UUID': 'C8E3FE05-1B7D-4462-85AB-97E58EEE8F0F',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191082,
#    'Title': '15 Bloesemstraat',
#    'AddressLine1': '15 Bloesemstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581XA',
#    'CountryID': 159,
#    'Latitude': 52.08818594300041,
#    'Longitude': 5.133346335065994,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309317,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:32:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190722,
#   'UUID': 'A3D2C5D0-A3FF-4BA2-AAA1-3926D20E7214',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191081,
#    'Title': 'Minervaplein',
#    'AddressLine1': 'Minervaplein',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581XP',
#    'CountryID': 159,
#    'Latitude': 52.086329944695024,
#    'Longitude': 5.13538062577652,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309316,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:31:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190721,
#   'UUID': 'ED61E389-9A4F-4894-8F0C-44713020BEB6',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 191080,
#    'Title': '80 Bankstraat',
#    'AddressLine1': '80 Bankstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581LP',
#    'CountryID': 159,
#    'Latitude': 52.08692819056603,
#    'Longitude': 5.135704882230243,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309315,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:30:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190720,
#   'UUID': '43C7C227-2BA6-48BD-980D-00345CC6CB3A',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'AddressInfo': {'ID': 191079,
#    'Title': 'Willem de Zwijgerstraat',
#    'AddressLine1': 'Willem de Zwijgerstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583HA',
#    'CountryID': 159,
#    'Latitude': 52.0872231173976,
#    'Longitude': 5.14253424432502,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309314, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:27:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:26:00Z',
#   'ID': 190719,
#   'UUID': '0596ACEF-1774-4185-B2EA-324F7B3CFED8',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'UsageCost': '0,36 per kWh',
#   'AddressInfo': {'ID': 191078,
#    'Title': 'Dillenburgstraat',
#    'AddressLine1': 'Dillenburgstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3583VA',
#    'CountryID': 159,
#    'Latitude': 52.08916478875773,
#    'Longitude': 5.142193386030044,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309313, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:26:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:23:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:27:00Z',
#   'ID': 190718,
#   'UUID': '1BEBBF07-62A2-4012-A391-0B4680D226FB',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'UsageCost': '0,36 per kWh',
#   'AddressInfo': {'ID': 191077,
#    'Title': 'Van Alphenplein',
#    'AddressLine1': 'Van Alphenplein',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581JE',
#    'CountryID': 159,
#    'Latitude': 52.091717725238425,
#    'Longitude': 5.138035548936045,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309312, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:22:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:27:00Z',
#   'ID': 190717,
#   'UUID': '4AAA04A5-D7D1-4C65-94B1-A2308FC480C2',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'UsageCost': '0,36 per kWh',
#   'AddressInfo': {'ID': 191076,
#    'Title': 'Wolter Heukelslaan',
#    'AddressLine1': 'Wolter Heukelslaan',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581SR',
#    'CountryID': 159,
#    'Latitude': 52.091365709776454,
#    'Longitude': 5.13593364135636,
#    'DistanceUnit': 0},
#   'Connections': [],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:20:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:27:00Z',
#   'ID': 190716,
#   'UUID': '3FB5CF9D-C84D-40D7-881D-F3B3A74047B7',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'UsageCost': '0,36 per kWh',
#   'AddressInfo': {'ID': 191075,
#    'Title': 'Oudwijkerveldstraat',
#    'AddressLine1': 'Oudwijkerveldstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581JP',
#    'CountryID': 159,
#    'Latitude': 52.090672992999174,
#    'Longitude': 5.139545855576216,
#    'DistanceUnit': 0},
#   'Connections': [],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:18:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:27:00Z',
#   'ID': 190715,
#   'UUID': '711B010A-EC9D-4F3E-99E7-C7277280E339',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'UsageCost': '0,36 per kWh',
#   'AddressInfo': {'ID': 191074,
#    'Title': 'Baanstraat',
#    'AddressLine1': 'Baanstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581VV',
#    'CountryID': 159,
#    'Latitude': 52.08811463525973,
#    'Longitude': 5.137616741754414,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309311, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:16:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:27:00Z',
#   'ID': 190714,
#   'UUID': 'BEA7E1CE-0C32-4C3C-A5CB-629FF50DC784',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'UsageCost': '0,36 per kWh',
#   'AddressInfo': {'ID': 191073,
#    'Title': 'Wilhelminapark',
#    'AddressLine1': 'Wilhelminapark',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581NA',
#    'CountryID': 159,
#    'Latitude': 52.088493461073995,
#    'Longitude': 5.138207920472382,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309310, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:15:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:27:00Z',
#   'ID': 190713,
#   'UUID': 'B136987B-E543-4546-832E-92FA6B2F586A',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 5,
#   'UsageCost': '0,36 per kWh',
#   'AddressInfo': {'ID': 191072,
#    'Title': 'Van der Duijnstraat',
#    'AddressLine1': 'Van der Duijnstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581JW',
#    'CountryID': 159,
#    'Latitude': 52.08956879970452,
#    'Longitude': 5.137197575874552,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309309, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:11:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-19T21:27:00Z',
#   'ID': 190712,
#   'UUID': '9360476B-6C11-4C63-A7FC-F40A266BE863',
#   'DataProviderID': 1,
#   'UsageTypeID': 5,
#   'UsageCost': '0,36 per kWh',
#   'AddressInfo': {'ID': 191071,
#    'Title': 'Prinsenstraat',
#    'AddressLine1': 'Prinsenstraat',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3581JT',
#    'CountryID': 159,
#    'Latitude': 52.09016646756268,
#    'Longitude': 5.138294360708983,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 309308, 'ConnectionTypeID': 0, 'StatusTypeID': 50}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-19T21:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-19T12:09:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-13T13:27:00Z',
#   'ID': 190544,
#   'UUID': '1A0B9E60-478B-4952-ADA7-09EFD48FEC64',
#   'DataProviderID': 1,
#   'OperatorID': 3299,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 190903,
#    'Title': 'IONITY Overbroek',
#    'AddressLine1': 'Overbroek',
#    'Town': 'Opheusden',
#    'StateOrProvince': 'Gelderland',
#    'Postcode': '4051CZ',
#    'CountryID': 159,
#    'Latitude': 51.921616,
#    'Longitude': 5.603749,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 308924,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 350.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-13T13:27:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-12T13:28:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-13T13:52:00Z',
#   'ID': 190533,
#   'UUID': '658CD82B-BB40-4502-8952-6C90C20037BE',
#   'DataProviderID': 1,
#   'OperatorID': 3299,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 190892,
#    'Title': 'IONITY De Knoest',
#    'AddressLine1': 'De Knoest',
#    'Town': 'Nieuwegein',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3433NW',
#    'CountryID': 159,
#    'Latitude': 52.014598,
#    'Longitude': 5.122174,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 308913,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 350.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-13T13:52:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-12T12:37:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-13T13:57:00Z',
#   'ID': 190516,
#   'UUID': '492E0736-C5A8-4680-A35B-DA3D429975EA',
#   'DataProviderID': 1,
#   'OperatorID': 3299,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 190875,
#    'Title': 'IONITY Apeldoorn-Zuid',
#    'AddressLine1': 'Lange Amerikaweg',
#    'Town': 'Apeldoorn',
#    'StateOrProvince': 'Gelderland',
#    'Postcode': '7332BR',
#    'CountryID': 159,
#    'Latitude': 52.1791,
#    'Longitude': 5.984281,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 308896,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 350.0,
#     'CurrentTypeID': 30,
#     'Quantity': 4}],
#   'NumberOfPoints': 4,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-13T13:57:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-12T11:32:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-12-03T11:13:00Z',
#   'ID': 190378,
#   'UUID': '02FB2074-0ABC-45C1-93DF-DAFB5BFFF1BD',
#   'DataProviderID': 1,
#   'OperatorID': 47,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 190737,
#    'Title': 'Shell Kooimeer',
#    'AddressLine1': 'Rijksweg A9 wz',
#    'Town': 'Alkmaar',
#    'Postcode': '1814 XE',
#    'CountryID': 159,
#    'Latitude': 52.61466842977481,
#    'Longitude': 4.73974268657912,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 308616,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 175.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2},
#    {'ID': 308643,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 70.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 4,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-12-03T11:13:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2021-12-02T10:07:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': True,
#   'DateLastVerified': '2021-11-07T10:04:00Z',
#   'ID': 189833,
#   'UUID': '038D8F66-5012-411A-8CB8-4B088FFD9569',
#   'DataProviderID': 1,
#   'OperatorID': 74,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 190192,
#    'Title': 'Fastned Bodegraven',
#    'AddressLine1': 'Bodegraven',
#    'Town': 'Bodegraven',
#    'StateOrProvince': 'South Holland',
#    'Postcode': '2411ZZ',
#    'CountryID': 159,
#    'Latitude': 52.06609674140043,
# ...
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-12-06T17:40:00Z',
#   'ID': 170696,
#   'UUID': '91DC78ED-334B-4A46-AC11-09EFE0AF55B0',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'UsageCost': '€0,30/kWh',
#   'AddressInfo': {'ID': 171055,
#    'Title': 'Dcb energy hub Schiphol',
#    'AddressLine1': 'Changing Lane 10',
#    'Town': 'Hoofddorp',
#    'StateOrProvince': 'North-Holland',
#    'CountryID': 159,
#    'Latitude': 52.271121182830655,
#    'Longitude': 4.69533813882299,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 260696,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 150.0,
#     'CurrentTypeID': 30,
#     'Quantity': 3},
#    {'ID': 260697,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 150.0,
#     'CurrentTypeID': 30,
#     'Quantity': 3},
#    {'ID': 260698,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 7},
#    {'ID': 260699,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 7}],
#   'NumberOfPoints': 10,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-12-06T17:40:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-12-05T14:15:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-12-02T16:01:00Z',
#   'ID': 170569,
#   'UUID': '9313E327-F050-449B-A8A0-5FADB5BC370B',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 2,
#   'AddressInfo': {'ID': 170928,
#    'Title': 'Flitsmeister',
#    'AddressLine1': 'Landjuweel 24',
#    'Town': 'Veenendaal',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3905PE',
#    'CountryID': 159,
#    'Latitude': 52.039305597053925,
#    'Longitude': 5.550275138520533,
#    'AccessComments': 'The charging pole on the left side when entering parking is restricted to employees only and will not operate on public charging cards.',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 260369,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 3.6,
#     'CurrentTypeID': 10,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-12-02T16:01:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-12-01T15:25:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-12-02T16:00:00Z',
#   'ID': 170568,
#   'UUID': 'D485AFBC-D22C-4855-A65C-047B24CFCB74',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 6,
#   'AddressInfo': {'ID': 170927,
#    'Title': '24 Landjuweel',
#    'AddressLine1': '24 Landjuweel',
#    'Town': 'Veenendaal',
#    'StateOrProvince': 'Utrecht',
#    'Postcode': '3905PG',
#    'CountryID': 159,
#    'Latitude': 52.03925546403201,
#    'Longitude': 5.550582310882078,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 260368,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-12-02T16:00:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-12-01T15:22:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-11-21T06:56:00Z',
#   'ID': 170229,
#   'UUID': '4DE679CF-EC96-40CF-835E-5A954E5D106D',
#   'DataProviderID': 1,
#   'OperatorID': 23,
#   'OperatorsReference': '34791',
#   'UsageTypeID': 4,
#   'UsageCost': "€0.25/kWh; andere tarieven voor oudere auto's",
#   'AddressInfo': {'ID': 170588,
#    'Title': 'Zuidbroek',
#    'AddressLine1': 'Burgemeester Otmaweg 2',
#    'Town': 'Zuidbroek',
#    'Postcode': '9636 EM',
#    'CountryID': 159,
#    'Latitude': 53.169567,
#    'Longitude': 6.852949,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 259569,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 120.0,
#     'CurrentTypeID': 30,
#     'Quantity': 8}],
#   'NumberOfPoints': 8,
#   'GeneralComments': 'Charging8 superchargers, available 24/7, up to 250kW',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-11-21T06:56:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-11-21T06:56:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-11-15T10:41:00Z',
#   'ID': 169959,
#   'UUID': 'D0C19B71-39F6-4FA4-B924-825D0EDF0165',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 170318,
#    'Title': 'Parking banjaardstrand',
#    'AddressLine1': 'Parking banjaardstrand',
#    'Town': 'Noord-Beveland',
#    'StateOrProvince': 'Zeeland',
#    'Postcode': '4493RA',
#    'CountryID': 159,
#    'Latitude': 51.590606301790416,
#    'Longitude': 3.6629008999134385,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 259007,
#     'ConnectionTypeID': 25,
#     'Reference': 'Agrisnellaad',
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 32,
#     'Voltage': 400,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 8}],
#   'NumberOfPoints': 8,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-11-15T10:41:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-11-15T03:23:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-10-29T07:32:00Z',
#   'ID': 169654,
#   'UUID': '35EAEABA-CBE1-427A-9A66-658BF15884ED',
#   'DataProviderID': 1,
#   'OperatorID': 1,
#   'UsageTypeID': 4,
#   'AddressInfo': {'ID': 170013,
#    'Title': 'Graaf Adolfstraat',
#    'AddressLine1': 'Graaf Adolfstraat',
#    'AddressLine2': 'Nieuwerbrug aan den Rijn',
#    'StateOrProvince': 'Zuid-Holland',
#    'Postcode': '2415AL',
#    'CountryID': 159,
#    'Latitude': 52.077645597481876,
#    'Longitude': 4.820435944502833,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 258297,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 230,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-10-29T07:32:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-10-28T12:56:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-10-14T05:34:00Z',
#   'ID': 169309,
#   'UUID': 'A058C3A8-45C0-4A37-9F14-ADE130D703AB',
#   'DataProviderID': 1,
#   'OperatorID': 23,
#   'OperatorsReference': '54677',
#   'UsageTypeID': 4,
#   'UsageCost': "€0.25/kWh; andere tarieven voor oudere auto's",
#   'AddressInfo': {'ID': 169668,
#    'Title': 'Leusden Supercharger',
#    'AddressLine1': 'Philipsstraat Leusden 18',
#    'Town': 'Utrecht',
#    'StateOrProvince': 'UT',
#    'Postcode': '3833',
#    'CountryID': 159,
#    'Latitude': 52.144022,
#    'Longitude': 5.416976,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 257602,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 120.0,
#     'CurrentTypeID': 30,
#     'Quantity': 12}],
#   'NumberOfPoints': 12,
#   'GeneralComments': '12 Superchargers, 250 kW available 24/7',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-10-14T05:34:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-10-14T05:34:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-10-14T05:32:00Z',
#   'ID': 169300,
#   'UUID': '9DE7D0C9-BA77-42B1-8DA4-03B95CFC8A5B',
#   'DataProviderID': 1,
#   'OperatorID': 23,
#   'OperatorsReference': '54678',
#   'UsageTypeID': 4,
#   'UsageCost': "€0.25/kWh; andere tarieven voor oudere auto's",
#   'AddressInfo': {'ID': 169659,
#    'Title': 'Uden Supercharger',
#    'AddressLine1': 'Rondweg 2',
#    'Town': 'Uden',
#    'CountryID': 159,
#    'Latitude': 51.671308,
#    'Longitude': 5.60267,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 257593,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 120.0,
#     'CurrentTypeID': 30,
#     'Quantity': 12}],
#   'NumberOfPoints': 12,
#   'GeneralComments': '12 Superchargers, 250 kW available 24/7',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-10-14T05:32:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-10-14T05:32:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-08-27T15:22:00Z',
#   'ID': 167143,
#   'UUID': '4F8CD1B0-6197-40BE-8AC5-5D99B88636D9',
#   'DataProviderID': 1,
#   'UsageTypeID': 1,
#   'UsageCost': 'Euro 0.55 kwh',
#   'AddressInfo': {'ID': 167502,
#    'Title': 'Boekhorstlaan 4',
#    'AddressLine1': '3847 LP',
#    'Town': 'Harderwijk',
#    'StateOrProvince': 'Gelderland',
#    'Postcode': '3847 LP',
#    'CountryID': 159,
#    'Latitude': 52.33570233192614,
#    'Longitude': 5.643056566499581,
#    'ContactEmail': 'info@tango.nl',
#    'AccessComments': 'opposite Burger King',
#    'RelatedURL': 'http://www.tango.nl/electric',
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 253114,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'PowerKW': 80.0,
#     'CurrentTypeID': 10}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-08-27T15:22:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-08-27T15:20:00Z',
#   'SubmissionStatusTypeID': 100},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-08-21T07:02:00Z',
#   'ID': 163019,
#   'UUID': 'C885AE1E-3ADE-416C-B42E-3B3BB9AC3655',
#   'DataProviderID': 1,
#   'OperatorID': 103,
#   'UsageTypeID': 4,
#   'UsageCost': '0,29 Euro/ kWh (incl BTW)',
#   'AddressInfo': {'ID': 163376,
#    'Title': 'Achterweg 1, Onderdendam',
#    'AddressLine1': 'Achterweg 1',
#    'Town': 'Onderdendam',
#    'StateOrProvince': 'Groningen',
#    'Postcode': '9959 PC',
#    'CountryID': 159,
#    'Latitude': 53.3353029,
#    'Longitude': 6.5879694,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 234571,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-08-21T07:02:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-08-19T09:23:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-08-13T07:41:00Z',
#   'ID': 162620,
#   'UUID': '5EEFFA56-457A-4999-B680-1D70F99BC984',
#   'DataProviderID': 1,
#   'OperatorID': 108,
#   'UsageTypeID': 1,
#   'UsageCost': '€0.34/kWh',
#   'AddressInfo': {'ID': 162977,
#    'Title': '9 Doornkampsteeg',
#    'AddressLine1': '9 Doornkampsteeg',
#    'Town': "'s-Hertogenbosch",
#    'StateOrProvince': 'North Brabant',
#    'Postcode': '5236BB',
#    'CountryID': 159,
#    'Latitude': 51.733641519305564,
#    'Longitude': 5.328723169128807,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 234061,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 32,
#     'Voltage': 400,
#     'PowerKW': 22.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-08-13T07:41:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-08-12T15:22:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-08-08T15:22:00Z',
#   'ID': 162393,
#   'UUID': '729A5A24-793A-4373-88BE-C3D92F9E8316',
#   'DataProviderID': 1,
#   'OperatorID': 108,
#   'UsageTypeID': 5,
#   'AddressInfo': {'ID': 162750,
#    'Title': 'Wolkammersstraat',
#    'AddressLine1': 'Wolkammersstraat',
#    'AddressLine2': 'Sneek',
#    'Town': 'Súdwest-Fryslân',
#    'StateOrProvince': 'Friesland',
#    'Postcode': '8601VB',
#    'CountryID': 159,
#    'Latitude': 53.034881824005396,
#    'Longitude': 5.622067875116045,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 233733,
#     'ConnectionTypeID': 33,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 233734,
#     'ConnectionTypeID': 2,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 50.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1},
#    {'ID': 233735,
#     'ConnectionTypeID': 1036,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 43.0,
#     'CurrentTypeID': 30,
#     'Quantity': 1}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-08-08T15:22:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-08-07T11:38:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-08-07T07:28:00Z',
#   'ID': 162363,
#   'UUID': '80E8E2BF-FB06-43AA-B59A-749122A3FDF4',
#   'DataProviderID': 1,
#   'OperatorID': 73,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 162720,
#    'Title': 'Koningin Emmaplein 15',
#    'AddressLine1': 'Koningin Emmaplein 15',
#    'Town': 'Rotterdam',
#    'Postcode': '3015AB',
#    'CountryID': 159,
#    'Latitude': 51.910371730587144,
#    'Longitude': 4.474995764763207,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 233696,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-08-07T07:28:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-08-07T04:50:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-08-07T07:30:00Z',
#   'ID': 162362,
#   'UUID': 'CBF1327D-F018-4B4F-AA50-179F1E7EDA12',
#   'DataProviderID': 1,
#   'OperatorID': 73,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 162719,
#    'Title': 'Van Vollenhovenstraat 3',
#    'AddressLine1': 'Van Vollenhovenstraat 3',
#    'Town': 'Rotterdam',
#    'StateOrProvince': 'South Holland',
#    'Postcode': '3016BH',
#    'CountryID': 159,
#    'Latitude': 51.910460915596104,
#    'Longitude': 4.477087146797885,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 233695,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 1,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-08-07T07:30:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-08-07T04:47:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2020-08-04T18:17:00Z',
#   'ID': 162064,
#   'UUID': '4AD2BE24-2AD6-4DFE-8298-C69202948ED6',
#   'DataProviderID': 1,
#   'OperatorID': 108,
#   'UsageTypeID': 1,
#   'AddressInfo': {'ID': 162421,
#    'Title': 'Honthorststraat',
#    'AddressLine1': 'Honthorststraat 46',
#    'Town': 'Amsterdam',
#    'StateOrProvince': 'Noord-Holland',
#    'Postcode': '1071DH',
#    'CountryID': 159,
#    'Latitude': 52.35769059255907,
#    'Longitude': 4.88575757377555,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 233252,
#     'ConnectionTypeID': 25,
#     'StatusTypeID': 50,
#     'LevelID': 2,
#     'Amps': 16,
#     'Voltage': 400,
#     'PowerKW': 11.0,
#     'CurrentTypeID': 20,
#     'Quantity': 2}],
#   'NumberOfPoints': 2,
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2020-08-04T18:17:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-08-01T10:57:00Z',
#   'SubmissionStatusTypeID': 200},
#  {'IsRecentlyVerified': False,
#   'DateLastVerified': '2021-01-07T06:55:00Z',
#   'ID': 161875,
#   'UUID': '4F9A83B2-B1D8-4734-82D3-FBD75D0FCAE8',
#   'DataProviderID': 1,
#   'OperatorID': 23,
#   'OperatorsReference': '54156',
#   'UsageTypeID': 4,
#   'UsageCost': "€0.25/kWh; andere tarieven voor oudere auto's",
#   'AddressInfo': {'ID': 162232,
#    'Title': 'Middelburg Supercharger',
#    'AddressLine1': 'Paukenweg 3',
#    'Town': 'Middelburg',
#    'Postcode': '4337 WH',
#    'CountryID': 159,
#    'Latitude': 51.480275,
#    'Longitude': 3.636485,
#    'DistanceUnit': 0},
#   'Connections': [{'ID': 232972,
#     'ConnectionTypeID': 27,
#     'StatusTypeID': 50,
#     'LevelID': 3,
#     'PowerKW': 120.0,
#     'CurrentTypeID': 30,
#     'Quantity': 2}],
#   'NumberOfPoints': 8,
#   'GeneralComments': 'Charging8 Superchargers, available 24/7, up to 250kW',
#   'StatusTypeID': 50,
#   'DateLastStatusUpdate': '2021-01-07T06:55:00Z',
#   'DataQualityLevel': 1,
#   'DateCreated': '2020-07-27T14:47:00Z',
#   'SubmissionStatusTypeID': 200}]

# %%
###Dataframe bevat kolom die een list zijn. 
#Met json_normalize zet je de eerste kolom om naar losse kolommen
Laadpalen = pd.json_normalize(repsonsejson)
#Daarna nog handmatig kijken welke kolommen over zijn in dit geval Connections
#Kijken naar eerst laadpaal op de locatie
#Kan je uitpakken middels:
df4 = pd.json_normalize(Laadpalen.Connections)
df5 = pd.json_normalize(df4[0])
df5.head()
###Bestanden samenvoegen
Laadpalen = pd.concat([Laadpalen, df5], axis=1)
Laadpalen.head()
# Out:
#    IsRecentlyVerified      DateLastVerified      ID  \
# 0                True  2022-02-21T22:09:00Z  191685
# 1                True  2022-02-22T08:20:00Z  191683
# 2                True  2022-02-07T08:54:00Z  191365
# 3                True  2021-12-29T14:57:00Z  190860
# 4                True  2021-12-29T14:58:00Z  190859
#
#                                    UUID  DataProviderID  OperatorID  \
# 0  006EEA5F-8258-4179-AC33-4EB27C157A78               1         1.0
# 1  F9A89AA7-6DF3-4206-9E8B-8C67AA1090AD               1        45.0
# 2  E7FF6AE2-F8C2-4F06-9676-810854CA488F               1        38.0
# 3  29C2D400-F957-4E36-8069-B4416ABDBA3F               1       103.0
# 4  CF7FA27E-7D98-42F0-A4E6-B870D890109A               1      3387.0
#
#    UsageTypeID                                        Connections  \
# 0            4  [{'ID': 311293, 'ConnectionTypeID': 25, 'Statu...
# 1            6  [{'ID': 311291, 'ConnectionTypeID': 25, 'Statu...
# 2            1  [{'ID': 310649, 'ConnectionTypeID': 2, 'Status...
# 3            4  [{'ID': 309557, 'ConnectionTypeID': 0, 'Status...
# 4            4  [{'ID': 309556, 'ConnectionTypeID': 25, 'Statu...
#
#    NumberOfPoints  StatusTypeID  ... ConnectionTypeID  StatusTypeID LevelID  \
# 0               2            50  ...             25.0          50.0     2.0
# 1               5            50  ...             25.0          50.0     2.0
# 2               2            50  ...              2.0          50.0     3.0
# 3               2            50  ...              0.0          50.0     2.0
# 4              12            50  ...             25.0          50.0     2.0
#
#     Amps  Voltage PowerKW CurrentTypeID Quantity Reference Comments
# 0   16.0    400.0    11.0          20.0      2.0       NaN      NaN
# 1   16.0    400.0    11.0          20.0      5.0       NaN      NaN
# 2  120.0    400.0    50.0          30.0      1.0       NaN      NaN
# 3   16.0    400.0    11.0          20.0      2.0       NaN      NaN
# 4   32.0    400.0    22.0          20.0     12.0       NaN      NaN
#
# [5 rows x 43 columns]
